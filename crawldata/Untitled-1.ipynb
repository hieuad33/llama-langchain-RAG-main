# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No CUDA device found")
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
from bs4 import BeautifulSoup
import requests
import pdfkit

# URL của trang web bạn muốn lấy dữ liệu


# Lấy nội dung của trang web
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Tìm tất cả các phần tử trong class "detail"
detail_elements = soup.find_all(class_='detail')

# Tạo nội dung HTML từ các phần tử detail
data = ""
for element in detail_elements:
    data += str(element) + "<br>"
print(data)
# Tạo file HTML tạm thời
with open('temp.html', 'w', encoding='utf-8') as file:
    file.write(data)

# Chuyển file HTML thành file PDF
pdfkit.from_file('temp.html', 'output.pdf')

# Xóa file HTML tạm thời
import os
os.remove('temp.html')

print("PDF đã được tạo thành công!")
# Out:
# PDF đã được tạo thành công!

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_website(url, output_file,pro):
    try:
            # Send a GET request to the URL
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        # Lấy nội dung của trang web
        response = requests.get(url, headers=headers)

        response.raise_for_status()  # Check for any HTTP error

        # Parse the HTML content of the webpage
        soup = BeautifulSoup(response.content, 'html.parser')
        ss=soup.find_all(class_=" tab-content 
                         ")[0]
        # Lấy nội dung HTML đã loại bỏ CSS và JavaScript
      
        #print(cleaned_html)
        # Extract text from HTML
        all_text = ""
        for style in soup.find_all('script'):
            style.decompose()
        print(type(ss))
        for tag in ss:
            
            if tag.name != None:
                for tag1 in tag:
                    print(tag1.name)
                    if(tag1.name!= 'h2'):
                        text = tag1.get_text(separator='\n', strip=True)
                    else:
                        text = tag1.get_text(separator=' ', strip=True)
                    if text:
                        all_text += text + "\n"
            else:
                
                text = tag.get_text(separator=' ', strip=True)
                if text:
                    all_text += text + "\n" 
        all_text= f"Tên sản phẩm: {pro.name}, Giá: {pro.price} VNĐ, thông tin chi tiết của sản phẩm: {all_text}"
        # Write the extracted text to a text file
        with open(output_file, 'w', encoding='utf-8') as file:
            file.write(all_text)

        print(f"Text content extracted from {url} and saved to {output_file} successfully.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching content from URL: {e}")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    # Replace 'URL_OF_WEBSITE' with the actual URL of the website you want to extract text from
    website_url = "https://www.thegioididong.com/dtdd/oppo-find-n5"
    
    # Specify the file path where you want to save the extracted text
    output_file_path = "output.txt"

    extract_text_from_website(website_url, output_file_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 61
#      58 # Specify the file path where you want to save the extracted text
#      59 output_file_path = "output.txt"
# ---> 61 extract_text_from_website(website_url, output_file_path)
#
# TypeError: extract_text_from_website() missing 1 required positional argument: 'pro'

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_website(url, output_file):
    try:
            # Send a GET request to the URL
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

        # Lấy nội dung của trang web
        response = requests.get(url, headers=headers)
    
        
        response.raise_for_status()  # Check for any HTTP error

        # Parse the HTML content of the webpage
        soup = BeautifulSoup(response.content, 'html.parser')
        ss=soup.find_all(class_="divContent")[0]
        # Lấy nội dung HTML đã loại bỏ CSS và JavaScript
      
        #print(cleaned_html)
        # Extract text from HTML
        all_text = ""
        for style in soup.find_all('script'):
            style.decompose()
        for style in soup.find_all(class_='boxpromote'):
            style.decompose()
        print(type(ss))
        for tag in ss:
            print(tag.name)
            if tag.name != None:
                print(1)
                for tag1 in tag:
                    text = tag1.get_text(separator=' ', strip=True)
                    if text:
                        all_text += text + "\n"
            else:
                print(2)
                text = tag.get_text(separator=' ', strip=True)
                if text:
                    all_text += text + "\n"   

        # Write the extracted text to a text file
        with open(output_file, 'w', encoding='utf-8') as file:
            file.write(all_text)

        print(f"Text content extracted from {url} and saved to {output_file} successfully.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching content from URL: {e}")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    # Replace 'URL_OF_WEBSITE' with the actual URL of the website you want to extract text from
    website_url = "https://www.thegioididong.com/hoi-dap/sim-dien-thoai-co-dung-cho-ipad-duoc-khong-642431"
    
    # Specify the file path where you want to save the extracted text
    output_file_path = "outputhh.txt"

    extract_text_from_website(website_url, output_file_path)
# Out:
# <class 'bs4.element.Tag'>
# None
# 2
# div
# 1
# None
# 2
# div
# 1
# None
# 2
# Text content extracted from https://www.thegioididong.com/hoi-dap/sim-dien-thoai-co-dung-cho-ipad-duoc-khong-642431 and saved to outputhh.txt successfully.

# %%
#from langchain_community.embeddings.ollama import OllamaEmbeddings
from langchain_openai import OpenAIEmbeddings


# could use this OLlama embeddings for local LLM 
#from langchain_community.embeddings.ollama import OllamaEmbeddings
from langchain_ollama import OllamaEmbeddings
# def get_embedding_function():
#     # llama3: https://ollama.com/library/llama3
#     embeddings = OllamaEmbeddings(model="nomic-embed-text")
#     return embeddings


# def get_embedding_function():
#     #embeddings = OpenAIEmbeddings()
#     embeddings = OllamaEmbeddings(model="llama3:8b-instruct-q4_0")
#     return embeddings
from langchain_community.embeddings import HuggingFaceEmbeddings
import torch

def get_embedding_function():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")
    embeddings = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large", model_kwargs={'device': device})
    return embeddings

# %%
import argparse
import shutil
import json
import os
import csv
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_community.vectorstores import Chroma

from langchain.schema import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document
#from langchain_chroma import Chroma

from dotenv import load_dotenv
from PyPDF2 import PdfReader
load_dotenv()
# openai_api_key = os.getenv('OPENAI_API_KEY')

CHROMA_PATH = "/chroma"
DATA_PATH = "./ccs"

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--reset", action="store_true", help="Reset the database.")
    args = parser.parse_args()
    if args.reset:
        print("✨ Clearing Database")
        clear_database()

    documents = load_documents()
    chunks = split_documents(documents)
    chunks = calculate_chunk_ids(chunks)  # Ensure IDs are assigned
    add_to_chroma(chunks)

def load_documents():
    documents = []
    for filename in os.listdir(DATA_PATH):
        file_path = os.path.join(DATA_PATH, filename)
        
        # Case 1: txt file
        if filename.endswith('.txt'):
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                qa_pairs = content.split('\n\n')  # Assuming each Q&A pair is separated by two newlines
                for qa_pair in qa_pairs:
                    if qa_pair.strip():  # Avoid empty Q&A pairs
                        # Each Q&A pair is a document
                        documents.append(Document(page_content=qa_pair.strip(), metadata={"source": filename}))

        # Case 2: jsonl file
        if filename.endswith('.jsonl'):
            # Read the JSON Lines file and process each line
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    if line.strip(): # ensure the line is not empty
                        json_line = json.loads(line.strip())
                        prompt = json_line.get('prompt', '')
                        completion = json_line.get('completion', '')
                        content = prompt + " " + completion
                        documents.append(Document(page_content=content, metadata={"source": filename}))

    
        
        # Case 3: pdf file (using pdfplumber)
        if filename.endswith('.pdf'):
            try:
                import pdfplumber
                with pdfplumber.open(file_path) as pdf:
                    for page_num, page in enumerate(pdf.pages, start=1):
                        text = page.extract_text()
                        if text.strip():  # Only add non-empty pages
                            documents.append(
                                Document(
                                    page_content=text,
                                    metadata={
                                        "source": filename,
                                        "page": page_num,
                                        "total_pages": len(pdf.pages)
                                    }
                                )
                            )
            except Exception as e:
                print(f"Error processing PDF file {filename}: {str(e)}")
                
        if filename.endswith('.csv'):
                try:
                    with open(file_path, 'r', encoding='utf-8') as file:
                        csv_reader = csv.DictReader(file)
                        for row_num, row in enumerate(csv_reader, start=1):
                            # Convert row to string representation
                            content = "\n".join(f"{k}: {v}" for k, v in row.items())
                            documents.append(
                                Document(
                                    page_content=content,
                                    metadata={
                                        "source": filename,
                                        "row": row_num,
                                        "headers": list(row.keys())
                                    }
                                )
                            )
                except Exception as e:
                    print(f"Error processing CSV file {filename}: {str(e)}")    
        # Implement other cases if possible/necessary
    return documents

def count_words(text: str) -> int:
    """Đếm số lượng từ trong một chuỗi văn bản."""
    return len(text.split())
def split_documents(documents):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=125, chunk_overlap=80, length_function=count_words, is_separator_regex=True)
    chunks = []
    for doc in documents:
        # Ensure to use the correct attribute 'page_content'
        doc_chunks = text_splitter.split_text(doc.page_content)
        for chunk in doc_chunks:
            chunks.append(Document(page_content=chunk, metadata=doc.metadata))
    return chunks


def add_to_chroma(chunks):
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=get_embedding_function())
    existing_items = db.get(include=[])  # This returns a dictionary with different categories

    # Directly access the 'ids' key, which contains a list of existing IDs
    existing_ids = set(existing_items['ids']) if existing_items.get('ids') is not None else set()

    print(f"Number of existing documents in DB: {len(existing_ids)}")

    new_chunks = [chunk for chunk in chunks if chunk.metadata["id"] not in existing_ids]
    if new_chunks:
        print(f"👉 Adding new documents: {len(new_chunks)}")
        batch_size = 166
        for i in range(0, len(new_chunks), batch_size):
            batch = new_chunks[i:i + batch_size]
            db.add_documents(batch)
        #db.persist()
    else:
        print("✅ No new documents to add")

def calculate_chunk_ids(chunks):
    last_page_id = None
    current_chunk_index = 0
    for chunk in chunks:
        current_page_id = f"{chunk.metadata['source']}:{chunk.metadata.get('page', 'N/A')}" # the page number is for PDFs
        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0
            last_page_id = current_page_id
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        chunk.metadata["id"] = chunk_id
    return chunks

def clear_database():
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

# %%
documents = load_documents()

# %%
from langchain_community.vectorstores import Chroma
import os
import csv
import chromadb
import torch
from langchain_community.embeddings import HuggingFaceEmbeddings
import torch
def get_embedding_function():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")
    embeddings = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-large", model_kwargs={'device': device})
    return embeddings

# %%
documents = []
metadatas = []
ids = []

with open(".\ccs\products_inf.csv", 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        metadata = {
            'id': row[1],
            'name': row[2],
            'category': row[3],
            'price':  row[4],
            'description': row[7],
            'url': row[5],
            'url_img': row[6],
            
        }
        documents.append(row[2]+" "+row[4]+" "+row[7])
        metadatas.append(metadata)
        ids.append(row[1])
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_25960\1769283463.py:5: SyntaxWarning: invalid escape sequence '\c'
#   with open(".\ccs\products_inf.csv", 'r', encoding='utf-8') as file:

# %%
documents
# Out:
# ['OPPO Find X8 5G 16GB/512GB 22.990.000₫ OPPO Find X8 thu hút sự chú ý với thiết kế viền màn hình siêu mỏng, mang lại vẻ đẹp hiện đại và tinh tế. Kích thước nhỏ gọn giúp dễ dàng thao tác bằng một tay, trong khi khả năng chụp ảnh vượt trội và thời lượng pin lâu dài khiến sản phẩm càng thêm hấp dẫn. Vẻ ngoài cao cấp, thanh lịch từng đường nét Về thiết kế, điện thoại OPPO Find X8 mang dáng vẻ hiện đại với kiểu dáng khá vuông vức cùng các góc được bo cong nhẹ nhàng, tạo cảm giác mạnh mẽ nhưng không quá cứng nhắc. Phần khung viền máy được làm từ chất liệu nhôm siêu nhẹ, tăng thêm sự cao cấp của tổng thể sản phẩm, thu hút người dùng ngay từ ánh nhìn đầu tiên. Bên cạnh đó, thiết bị chỉ nặng 193 gram, một con số hợp lý để bạn cầm lâu mà không bị mỏi tay. Điều này khiến điện thoại trở thành một lựa chọn hấp dẫn với những ai yêu thích sự nhẹ nhàng và thường có thói quen sử dụng liên tục. Với tiêu chuẩn IP69 và IP68 cùng chứng nhận 5 sao SGS về khả năng chống rơi vỡ, mang đến cho người dùng sự 
# ...

# %%
save_folder='demo'
client = chromadb.PersistentClient(path=save_folder)

embedding=get_embedding_function()
product_collection = client.create_collection(
    name="my_collection_cohere",
   
)

product_collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids
)
# Out:
# Using device: cuda

# %%
# Define the text input you want to use as a query
query = "Chọn mua laptop gaming cần xét kích thước (14-15 inch cho di chuyển, 17 inch cho cố định), màn hình (Full HD 15.6 inch, 17 inch hiển thị tốt hơn), CPU (tối thiểu Core i5, phổ biến Core i7), RAM (8GB đủ, 16GB tốt hơn), ổ cứng (HDD dung lượng lớn, SSD tùy chọn cho tốc độ), GPU (GTX 1050 trở lên cho game trung bình khá) và hệ thống tản nhiệt tốt để chơi game mượt mà"

# Perform the query with the text input
query_results = product_collection.query(
    query_texts=query,
    n_results=7,
    #using the 'where' condition for filtering based on category and price
    # where={
    #     '$and': [
    #         {'name': {'$eq': 'Electronics'}},
    #         {'price': {'$gte': 100}},
    #         {'price': {'$lte': 500}}
    #     ]
    # }
    
)

# Extract metadata from query results
data = query_results.get('metadatas', [])

print(metadata)
# Out:
# {'id': '294', 'name': 'OPPO Pad 3 Pro 12GB/256GB', 'category': 'may-tinh-bang', 'price': '-1', 'description': 'OPPO Pad 3 Pro là chiếc máy tính bảng lý tưởng cho những ai đam mê sáng tạo. Trang bị vi xử lý mạnh mẽ từ Qualcomm cùng các tính năng AI độc đáo, Pad 3 Pro mang đến hiệu suất ấn tượng, giúp xử lý mượt mà mọi tác vụ từ thiết kế đồ họa đến chỉnh sửa video. Chip xử lý chuẩn đồ họa, cho khả năng vẽ mượt mà OPPO Pad 3 Pro được trang bị con chip Snapdragon 8 Gen 3, sản xuất trên tiến trình 4 nm tiên tiến, đem đến không chỉ hiệu năng mạnh mẽ mà còn tối ưu năng lượng sử dụng, hỗ trợ người dùng xử lý nhanh gọn các công việc hằng ngày. Kết hợp hoàn hảo với Trinity Engine từ ColorOS, chiếc máy mang đến trải nghiệm mượt mà và liền mạch, từ việc lướt web, xem phim cho đến hoàn thành các công việc hằng ngày. Bên cạnh đó, với xung nhịp lên đến 3.4 GHz, vi xử lý giúp tối ưu hiệu suất, xử lý tốt các ứng dụng nặng và chơi game cấu hình cao một cách dễ dàng. GPU Adreno 750 trên chiếc máy tính 
# ...

# %%
for i in data[0]:
    print(i['name'])
# Out:
# Lenovo LOQ 15IAX9E i5 12450HX (83LK000BVN)
# Lenovo Gaming LOQ 15IAX9 i5 12450HX (83GS00D9VN)
# Lenovo Gaming LOQ 15IAX9 i5 12450HX (83GS000JVN)
# Lenovo Gaming LOQ 15ARP9 R7 7435HS (83JC0040VN)
# HP Gaming VICTUS 15 fa1139TX i5 12450H (8Y6W3PA)
# Asus TUF Gaming F15 FX507ZC4 i5 12500H (HN330W)
# Lenovo Gaming LOQ 15IRX9 i7 13650HX (83DV00D5VN)

# %%
Document['source']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Document['source']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pydantic\main.py:858, in BaseModel.__class_getitem__(cls, typevar_values)
#     856     raise TypeError('Type parameters should be placed on typing.Generic, not BaseModel')
#     857 if not hasattr(cls, '__parameters__'):
# --> 858     raise TypeError(f'{cls} cannot be parametrized because it does not inherit from typing.Generic')
#     859 if not cls.__pydantic_generic_metadata__['parameters'] and typing.Generic not in cls.__bases__:
#     860     raise TypeError(f'{cls} is not a generic class')
#
# TypeError: <class 'langchain_core.documents.base.Document'> cannot be parametrized because it does not inherit from typing.Generic

# %%
chunks = split_documents(documents)

# %%
len(documents)
# Out:
# 326

# %%
len(chunks)
# Out:
# 13229

# %%
chunks[1]
# Out:
# Document(metadata={'source': 'Acer Aspire 3 A314 42P R3B3 R7 5700U NXKSFSV001.txt'}, page_content='Hư gì đổi nấy\n12 tháng\ntại 2958 siêu thị toàn quốc (miễn phí tháng đầu)\nXem chi tiết\nBảo hành\nchính hãng laptop 1 năm\ntại các trung tâm bảo hành hãng\nXem địa chỉ bảo hành\nCHÍNH SÁCH BẢO HÀNH, ĐỔI TRẢ\n✖\nBẢO HÀNH CHÍNH HÃNG\nThân máy 1 năm, pin 1 năm, sạc 1 năm\nXem điểm bảo hành Acer\nChính sách đổi trả\nChỉ cần số điện thoại mua hàng, không cần giấy tờ.\nLỗi do nhà sản xuất, Khách hàng chọn 1 trong 3 hình thức\nBảo hành có cam kết trong 12 tháng (chỉ áp dụng cho sản phẩm chính, KHÔNG áp dụng cho phụ kiện kèm theo)')

# %%
chunks[1].metadata,chunks[1].page_content
# Out:
# ({'source': 'Acer Aspire 3 A314 42P R3B3 R7 5700U NXKSFSV001.txt'},
#  'Hư gì đổi nấy\n12 tháng\ntại 2958 siêu thị toàn quốc (miễn phí tháng đầu)\nXem chi tiết\nBảo hành\nchính hãng laptop 1 năm\ntại các trung tâm bảo hành hãng\nXem địa chỉ bảo hành\nCHÍNH SÁCH BẢO HÀNH, ĐỔI TRẢ\n✖\nBẢO HÀNH CHÍNH HÃNG\nThân máy 1 năm, pin 1 năm, sạc 1 năm\nXem điểm bảo hành Acer\nChính sách đổi trả\nChỉ cần số điện thoại mua hàng, không cần giấy tờ.\nLỗi do nhà sản xuất, Khách hàng chọn 1 trong 3 hình thức\nBảo hành có cam kết trong 12 tháng (chỉ áp dụng cho sản phẩm chính, KHÔNG áp dụng cho phụ kiện kèm theo)')

# %%
i=35
chunks[i].metadata,chunks[i].page_content
# Out:
# ({'source': 'Acer Aspire 3 A314 42P R3B3 R7 5700U NXKSFSV001.txt'},
#  'Hữu ích (16)\nĐã dùng khoảng 3 tuần\nbùi tấn đô\nĐã mua tại TGDĐ\nSẽ giới thiệu cho bạn bè, người thân\nHữu ích (3)\nĐã dùng khoảng 1 ngày\nXem 6 đánh giá\nViết đánh giá')

# %%
print(chunks[i].metadata.get('source'))
# Out:
# Acer Aspire 3 A314 42P R3B3 R7 5700U NXKSFSV001.txt

# %%
chunks[i].metadata.get('source', 'N/A')
# Out:
# 'Acer Aspire 3 A314 42P R3B3 R7 5700U NXKSFSV001.txt'
